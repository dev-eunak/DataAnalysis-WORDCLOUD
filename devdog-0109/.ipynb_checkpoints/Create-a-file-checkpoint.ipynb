# %% [markdown]
# ### 1. 사용자가 입력한 단어와 연관된 뉴스 기사 제목 크롤링

# %%
import urllib
import urllib.parse
from bs4 import BeautifulSoup

plusUrl = urllib.parse.quote_plus(input('검색어를 입력하세요: '))
end = input('몇 페이지까지 크롤링을 하시겠습니까? ')

pageNum = 1
count = 1

result_list = []

lastPage = int(end) * 10 - 9
while(pageNum < lastPage + 1):
    url = f'https://search.naver.com/search.naver?&where=news&query={plusUrl}&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:r,p:all,a:all&mynews=0&cluster_rank=21&start={pageNum}'
    
    html = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')

    title = soup.find_all(class_='_sp_each_title')
    
    print(f'----------{count}페이지 결과입니다----------')
    for i in title:
        print(i.attrs['title'])
        result_list.append(i.attrs['title'] + '\n')
    print()
    
    pageNum += 10
    count += 1
# Out:
# 검색어를 입력하세요:  데이터 분석
# 몇 페이지까지 크롤링을 하시겠습니까?  20
# ----------1페이지 결과입니다----------
# [이슈분석]'시작이 반'…데이터경제 실현 마중물 확보
# 데이터경제 활성화 길 텄다…'데이터 3법' 본회의 통과(종합)
# 금융권 "데이터 활용 길 열려" 반색… 인프라 개선 박차
# 데이터금융시대 열린다 …씬파일러도 혜택
# 개인정보 유출 차단한 `가명 정보` 활용…韓 데이터 신사업 속도
# 국회 본회의, 데이터3법·연금3법·청년기본법 등 201건 의결
# '데이터 3법' 국회 통과…정부, TF 구성후 지원방안 발표
# 국회 문턱 넘은 '데이터 3법'…정부 "데이터 개방·유통 확대 나선다"
# 엔터프라이즈 데이터 분석 시장, AI 파워 점점 커진다
# 산업계 숙원 ‘데이터3법’ 법사위 문턱 넘어
#
# ----------2페이지 결과입니다----------
# 수자원공사 수문 데이터 측정 '국가표준' 공인
# "디지털 데이터 기반 사업 기회 모색"… 구자은 LS 혁신단장 CES 방문
# AI가 특허문서 분석부터 번역까지…카카오엔터프라이즈-특허청 맞손
# '데이터 3법' 국회 통과…개인정보 활용 탄력
# [이슈분석]데이터 3법, 대통령 발표부터 국회 통과까지
# 국회 법사위, '데이터 3법' 등 법률안 14건 전체회의 의결
# LG헬로비전, 지능형 광고 플랫폼 개발..."빅데이터와 만났다"
# [이슈분석]데이터센터, 클라우드·AI 시대 핵심 주목...글로벌 자본 몰려든다
# [이슈분석]'데이터3법' 통과로 개인정보 거버넌스도 재편
# 국회 본회의, 데이터3법·연금3법·청년기본법 등 201건 의결
#
# ----------3페이지 결과입니다----------
# [이슈분석]데이터경제 실현 위한 후속 법 개정 필요성 제기
# 한국수자원공사 수문 데이터, 국가표준 된다
# 경기도의 세계 최초 ‘데이터 주민배당’ 어떻게 가능하게 됐을까?
# KT, 5G 네트워크에 AI·빅데이터 적용한다...통신 품질 향상
# ...

# %% [markdown]
# ### 2. 크롤링한 뉴스 기사 제목 텍스트 파일로 저장

# %%
f = open('devdog.txt', 'w', encoding='utf-8')
for i in result_list:
    f.write(i)
f.close()
